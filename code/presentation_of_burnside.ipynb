# %%
# %env SAGE_MACAULAY2_COMMAND /opt/homebrew/bin/M2
# Out:
# env: SAGE_MACAULAY2_COMMAND=/opt/homebrew/bin/M2

# %%
def burnside_ring(G):
    matG = Matrix(ZZ, G.TableOfMarks().MatTom())
    nG = matG.dimensions()[0]
    baseRing = PolynomialRing(ZZ,'x',nG)
    baseGens = baseRing.gens()
    relations = [baseGens[nG-1]-1]
    for i in range(nG):
        for j in range(nG):
            relations.append(baseGens[i]*baseGens[j] - sum(coeff * baseGens[k] for k,coeff in enumerate(matG.solve_left(vector(ZZ, [matG[i][k] * matG[j][k] for k in range(nG)])))))
    return baseRing.quotient(relations)

def print_minimal_presentation(ring):
    print(macaulay2(ring).minimalPresentation())

# %%
G = gap("PSL(2,7)")
A_G = burnside_ring(G)
print_minimal_presentation(A_G)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ZZ[x5, x7, x8, x9, x10, x11, x12, x13]
# ---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
#    2   2                        2                                    2                   3         2                   2                                                             2                           2                                                                                                                                     2                      2                             2   2       2         2                                          2                                  3           2                                      2             2                                                                                                                    2                                                                                                                                                                                                        2         2                                                                                                                         2                                        2                        2                              2   2                               3          2                    2                                                                2                                                                                                                                                     2                                                                  2                            3         2                    3           2                                      3          2                4       3                 2            2   2      2             2                                              2                                              3         2          2                                             2                  2                                     2                      2                          2                2                                     2                             2                           2                  3                2               2                                    2             2                                                              2                                 2   2      2             2                                           4       3       2                         2                                          3            2      2                                                2                           2                2                                           2                                              2                 2                          2                         3       2                     2         2                                                                                                                                         2                                             2                                         2                                                                                                                                                                                                                                                                                                       2                                    2                                                                              2                                          3         2          2                                          3            2      2                                                                                             2   2                   2                                                                                          2                                                                                                                                                                                             2                                                      2                                              2                      ...
# (x7 x13  - 168x7*x13, x7*x10*x13  - x7*x10*x13 - 84x7*x13, x7*x11*x13  - 56x7*x13, x7*x13  - x7*x13  - 42x7*x13, x7*x12 x13 - x7*x12*x13 - 42x7*x13, x5*x7*x13 - 42x7*x13, x7*x12*x13  - x7*x8*x13 - 28x7*x13, x7 x13 - 24x7*x13, x7*x8*x13 - 21x7*x13, x7*x9*x13 - 14x7*x13, x7*x10*x13 - 14x7*x13, x7*x11*x13 - 8x7*x13, x7*x12*x13 - 7x7*x13, x7*x13  - 7x7*x13, x7*x10*x13  - x7*x10*x13 - 84x7*x13, x10 x13  - 2x10 x13 + x10  - 40x7*x13 - 4x10*x13 + 4x10, x10*x11*x13  - x10*x11*x13 - 28x7*x13, x10*x13  - 2x10*x13  - 18x7*x13 - 5x10*x13 + 6x10, x10*x12 x13 - x10*x12  - x10*x12*x13 + x10*x12 - 18x7*x13 - 6x10